# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataframe_bug = pd.read_csv("Bug_coherence.csv")
dataframe_nobug = pd.read_csv("NoBug_coherence.csv")

# %%
dataframe_nobug
# Out:
#          NoBug
# 0     0.206361
# 1     0.351803
# 2     0.379630
# 3     0.785670
# 4     0.237861
# ...        ...
# 2224  0.810247
# 2225  0.902454
# 2226  0.720724
# 2227  0.773304
# 2228  0.131696
#
# [2229 rows x 1 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataframe = pd.read_csv("winequality-red.csv")

fixed_acidity = dataframe["fixed acidity"]
free_sulfur_dioxide = dataframe['free sulfur dioxide']
total_sulfur_dioxide = dataframe['total sulfur dioxide']
alcohol = dataframe['alcohol']

columns = [fixed_acidity, free_sulfur_dioxide, total_sulfur_dioxide, alcohol]

fig, ax = plt.subplots()
ax.boxplot(columns)
plt.show()

# %%
bug = dataframe_bug["Bug"]
nobug = dataframe_nobug["NoBug"]

columns = [bug, nobug]

fig, ax = plt.subplots()
ax.boxplot(columns)
plt.xticks([1, 2], ["Bug", "No Bug"], rotation=0)

plt.show()

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import pandas as pd

# loading dataset
data = pd.read_csv("bug_nobug_coherence.csv")
  
sns.stripplot(x='Mood', y='Coherence', data=data)


# Show the plot
plt.show()

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import pandas as pd

# loading dataset
dataframe = pd.read_csv("bug_nobug_coherence.csv")


plt.figure(figsize=(10,6))
sns.set_palette("RdBu")
sns.set_style("darkgrid")

sns.violinplot(x='Mood', y='Coherence', data=dataframe)

# sns.violinplot(x='Mood', y='Coherence', data=dataframe)
# sns.swarmplot(x='Mood', y='Coherence', data=dataframe, color="k", alpha=0.8)

plt.title("Relationship between Inconsistent Code Comment with Software Bugs")
plt.ylabel("Coherence Value")
plt.xlabel("Code Status Bug or NoBug")

plt.show()
